# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
anime_data = pd.read_csv("anime.csv", index_col = 'anime_id')

# %%
anime_data
# Out:
#                                                        name  \
# anime_id
# 32281                                        Kimi no Na wa.
# 5114                       Fullmetal Alchemist: Brotherhood
# 28977                                              Gintama°
# 9253                                            Steins;Gate
# 9969                                          Gintama&#039;
# ...                                                     ...
# 9316           Toushindai My Lover: Minami tai Mecha-Minami
# 5543                                            Under World
# 5621                         Violence Gekiga David no Hoshi
# 6133      Violence Gekiga Shin David no Hoshi: Inma Dens...
# 26081                      Yasuji no Pornorama: Yacchimae!!
#
#                                                       genre   type episodes  \
# anime_id
# 32281                  Drama, Romance, School, Supernatural  Movie        1
# ...

# %%
top_ten = anime_data.head(11)

# %%
top_ten
# Out:
#                                                        name  \
# anime_id
# 32281                                        Kimi no Na wa.
# 5114                       Fullmetal Alchemist: Brotherhood
# 28977                                              Gintama°
# 9253                                            Steins;Gate
# 9969                                          Gintama&#039;
# 32935     Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
# 11061                                Hunter x Hunter (2011)
# 820                                    Ginga Eiyuu Densetsu
# 15335     Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
# 15417                              Gintama&#039;: Enchousen
# 4181                                   Clannad: After Story
#
#                                                       genre   type episodes  \
# anime_id
# 32281                  Drama, Romance, School, Supernatural  Movie        1
# ...

# %%
top_ten.loc[32281:4181, "name":'rating']
# Out:
#                                                        name  \
# anime_id
# 32281                                        Kimi no Na wa.
# 5114                       Fullmetal Alchemist: Brotherhood
# 28977                                              Gintama°
# 9253                                            Steins;Gate
# 9969                                          Gintama&#039;
# 32935     Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
# 11061                                Hunter x Hunter (2011)
# 820                                    Ginga Eiyuu Densetsu
# 15335     Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
# 15417                              Gintama&#039;: Enchousen
# 4181                                   Clannad: After Story
#
#                                                       genre   type episodes  \
# anime_id
# 32281                  Drama, Romance, School, Supernatural  Movie        1
# ...

# %%
top_ten["rating"].value_counts()
# Out:
# 9.11    2
# 9.37    1
# 9.26    1
# 9.25    1
# 9.17    1
# 9.16    1
# 9.15    1
# 9.13    1
# 9.10    1
# 9.06    1
# Name: rating, dtype: int64

# %%
ep_rating = top_ten[["episodes", "rating"]]

# %%
ep_rating.sum(axis=0)
# Out:
# episodes    1645124511014811011324
# rating                      100.87
# dtype: object

# %%
ep_rating
# Out:
#          episodes  rating
# anime_id
# 32281           1    9.37
# 5114           64    9.26
# 28977          51    9.25
# 9253           24    9.17
# 9969           51    9.16
# 32935          10    9.15
# 11061         148    9.13
# 820           110    9.11
# 15335           1    9.10
# 15417          13    9.11
# 4181           24    9.06

# %%
ep_rating.sort_index(ascending=False)
# Out:
#          episodes  rating
# anime_id
# 32935          10    9.15
# 32281           1    9.37
# 28977          51    9.25
# 15417          13    9.11
# 15335           1    9.10
# 11061         148    9.13
# 9969           51    9.16
# 9253           24    9.17
# 5114           64    9.26
# 4181           24    9.06
# 820           110    9.11

# %%
ep_rating.sort_values('rating', ascending= False)
# Out:
#          episodes  rating
# anime_id
# 32281           1    9.37
# 5114           64    9.26
# 28977          51    9.25
# 9253           24    9.17
# 9969           51    9.16
# 32935          10    9.15
# 11061         148    9.13
# 820           110    9.11
# 15417          13    9.11
# 15335           1    9.10
# 4181           24    9.06

# %%
name_rating = top_ten[["name", 'rating']]
name_rating
# Out:
#                                                        name  rating
# anime_id
# 32281                                        Kimi no Na wa.    9.37
# 5114                       Fullmetal Alchemist: Brotherhood    9.26
# 28977                                              Gintama°    9.25
# 9253                                            Steins;Gate    9.17
# 9969                                          Gintama&#039;    9.16
# 32935     Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...    9.15
# 11061                                Hunter x Hunter (2011)    9.13
# 820                                    Ginga Eiyuu Densetsu    9.11
# 15335     Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...    9.10
# 15417                              Gintama&#039;: Enchousen    9.11
# 4181                                   Clannad: After Story    9.06

# %%
fave_anime = anime_data[anime_data['name'] == 'Kimi no Na wa.']
fave_anime
# Out:
#                     name                                 genre   type  \
# anime_id
# 32281     Kimi no Na wa.  Drama, Romance, School, Supernatural  Movie
#
#          episodes  rating  members
# anime_id
# 32281           1    9.37   200630
